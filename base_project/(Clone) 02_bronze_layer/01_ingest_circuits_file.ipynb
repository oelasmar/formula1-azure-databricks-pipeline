# %% [markdown]
# ## Ingest ***circuits.csv*** file
# 1. Read the file using spark dataframe reader API
# 2. Add Metadata Columns
#      - Source File
#      - Ingestion Timestamp
# 3. Write to bronze delta table

# %% [markdown]
# #### Step 0 - Run configuration notebooks and set variables

# %%
# %run ../00_common/01_configuration

# %%
# %run ../00_common/02_bronze_functions

# %%
source_file = f"{landing_folder_path}/circuits.csv"
table_name = f"{catalog_name}.{bronze_schema}.circuits"

# %% [markdown]
# #### Step 1 - Read the CSV file using the dataframe reader API

# %%
from pyspark.sql.types import StructType, StructField, StringType, DoubleType

circuits_Schema = StructType([
                    StructField('circuitId'  , StringType()),
                    StructField('url'        , StringType()),
                    StructField('circuitName', StringType()),
                    StructField('lat'        , DoubleType()),
                    StructField('long'       , DoubleType()),
                    StructField('locality'   , StringType()),
                    StructField('country'    , StringType())
                ])

# %%
circuits_df = (
    spark.read
        .format('csv')
        .option('header', True)  # Used to skip the header row 
        #.option('inferSchema', True)  # Used to infer the data types. Possible issue --> goes through the data twice (read and infer the data types)
        .schema(circuits_Schema)  # Predefined schema
        .option('mode', 'failfast')  # Fail if there is any error reading the data (i.e. the readed data format is different from defined schema)
        .load(source_file)
)

# %%
circuits_df.show()
# Out:
# +------------+--------------------+--------------------+--------+--------+----------------+-----------+
# |   circuitId|                 url|         circuitName|     lat|    long|        locality|    country|
# +------------+--------------------+--------------------+--------+--------+----------------+-----------+
# |        NULL|https://en.wikipe...|circuit gilles vi...|    45.5|-73.5228|        montreal|     Canada|
# |        NULL|https://en.wikipe...|losail internatio...|   25.49| 51.4542|          lusail|      Qatar|
# |    adelaide|https://en.wikipe...|adelaide street c...|-34.9272| 138.617|        adelaide|  Australia|
# |    ain-diab|https://en.wikipe...|            ain diab| 33.5786| -7.6875|      casablanca|    Morocco|
# |     aintree|https://en.wikipe...|             aintree| 53.4769|-2.94056|       liverpool|         UK|
# | albert_park|https://en.wikipe...|albert park grand...|-37.8497| 144.968|       melbourne|  Australia|
# |    americas|https://en.wikipe...|circuit of the am...| 30.1328|-97.6411|          austin|        USA|
# |  anderstorp|https://en.wikipe...|scandinavian raceway| 57.2653| 13.6042|      anderstorp|     Sweden|
# |        avus|https://en.wikipe...|                avus| 52.4806| 13.2514|          berlin|    Germany|
# |     bahrain|https://en.wikipe...|bahrain internati...| 26.0325| 50.5106|          sakhir|    Bahrain|
# |        baku|https://en.wikipe...|   baku city circuit| 40.3725| 49.8533|            baku| Azerbaijan|
# |    boavista|https://en.wikipe...|circuito da boavista| 41.1705|-8.67325|          oporto|   Portugal|
# |brands_hatch|https://en.wikipe...|        brands hatch| 51.3569|0.263056|            kent|         UK|
# |  bremgarten|https://en.wikipe...|  circuit bremgarten| 46.9589| 7.40194|            bern|Switzerland|
# |       buddh|https://en.wikipe...|buddh internation...| 28.3487| 77.5331|   uttar pradesh|      India|
ands_hatch</td><td>https://en.wikipedia.org/wiki/Brands_Hatch</td><td>brands hatch</td><td>51.3569</td><td>0.263056</td><td>kent</td><td>UK</td></tr><tr><td>bremgarten</td><td>https://en.wikipedia.org/wiki/Circuit_Bremgarten</td><td>circuit bremgarten</td><td>46.9589</td><td>7.40194</td><td>bern</td><td>Switzerland</td></tr><tr><td>buddh</td><td>https://en.wikipedia.org/wiki/Buddh_International_Circuit</td><td>buddh international circuit</td><td>28.3487</td><td>77.5331</td><td>uttar pradesh</td><td>India</td></tr><tr><td>catalunya</td><td>https://en.wikipedia.org/wiki/Circuit_de_Barcelona-Catalunya</td><td>circuit de barcelona-catalunya</td><td>41.57</td><td>2.26111</td><td>barcelona</td><td>Spain</td></tr><tr><td>charade</td><td>https://en.wikipedia.org/wiki/Circuit_de_Charade</td><td>charade circuit</td><td>45.7472</td><td>3.03889</td><td>clermont-ferrand</td><td>France</td></tr><tr><td>dallas</td><td>https://en.wikipedia.org/wiki/Fair_Park</td><td>fair park</td><td>32.7774</td><td>-96.7587</td><td>dallas</td><td>USA</td></tr><tr><td>detroit</td><td>https://en.wikipedia.org/wiki/Detroit_street_circuit</td><td>detroit street circuit</td><td>42.3298</td><td>-83.0401</td><td>detroit</td><td>USA</td></tr><tr><td>dijon</td><td>https://en.wikipedia.org/wiki/Dijon-Prenois</td><td>dijon-prenois</td><td>47.3625</td><td>4.89913</td><td>dijon</td><td>France</td></tr><tr><td>dijon</td><td>https://en.wikipedia.org/wiki/Dijon-Prenois</td><td>dijon-prenois</td><td>47.3625</td><td>4.89913</td><td>dijon</td><td>France</td></tr><tr><td>donington</td><td>https://en.wikipedia.org/wiki/Donington_Park</td><td>don ...

# %% [markdown]
# #### Step 2 - Add Metadata Columns
# - Source File
# - Ingestion Timestamp

# %%
from pyspark.sql import functions as F
circuits_final_df = add_ingestion_metadata(circuits_df)

# %%
display(circuits_final_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>circuitId</th><th>url</th><th>circuitName</th><th>lat</th><th>long</th><th>locality</th><th>country</th><th>ingestion_timestamp</th><th>source_file</th></tr></thead><tbody><tr><td>null</td><td>https://en.wikipedia.org/wiki/Circuit_Gilles_Villeneuve</td><td>circuit gilles villeneuve</td><td>45.5</td><td>-73.5228</td><td>montreal</td><td>Canada</td><td>2026-08-10T18:42:17.271649Z</td><td>dbfs:/Volumes/formula1/landing/files/circuits.csv</td></tr><tr><td>null</td><td>https://en.wikipedia.org/wiki/Lusail_International_Circuit</td><td>losail international circuit</td><td>25.49</td><td>51.4542</td><td>lusail</td><td>Qatar</td><td>2026-08-10T18:42:17.271649Z</td><td>dbfs:/Volumes/formula1/landing/files/circuits.csv</td></tr><tr><td>adelaide</td><td>https://en.wikipedia.org/wiki/Adelaide_Street_Circuit</td><td>adelaide street circuit</td><td>-34.9272</td><td>138.617</td><td>adelaide</td><td>Australia</td><td>2026-08-10T18:42:17.271649Z</td><td>dbfs:/Volumes/formula1/landing/files/circuits.csv</td></tr><tr><td>ain-diab</td><td>https://en.wikipedia.org/wiki/Ain-Diab_Circuit</td><td>ain diab</td><td>33.5786</td><td>-7.6875</td><td>casablanca</td><td>Morocco</td><td>2026-08-10T18:42:17.271649Z</td><td>dbfs:/Volumes/formula1/landing/files/circuits.csv</td></tr><tr><td>aintree</td><td>https://en.wikipedia.org/wiki/Aintree_Motor_Racing_Circuit</td><td>aintree</td><td>53.4769</td><td>-2.94056</td><td>liverpool</td><td>UK</td><td>2026-08-10T18:42:17.271649Z</td><td>dbfs:/Volumes/formula1/landing/files/circuits.csv</td></tr><tr><td>albert_park</td><td>https://en.wikipedia.org/wiki/Albert_Park_Circuit</td><td>albert park grand prix circuit</td><td>-37.8497</td><td>144.968</td><td>melbourne</td><td>Australia</td><td>2026-08-10T18:42:17.271649Z</td><td>dbfs:/Volumes/formula1/landing/files/circuits.csv</td></tr><tr><td>americas</td><td>https://en.wikipedia.org/wiki/Circuit_of_the_Americas</td><td>circuit of the americas</td><td>30.1328</td><td>-97.6411</td><td>austin</td><td>USA</td><td>2026-08-10T18:42:17.271649Z</td><td>dbfs:/Volumes/formula1/landing/files/circuits.csv</td></tr><tr><td>anderstorp</td><td>https://en.wikipedia.org/wiki/Anderstorp_Raceway</td><td>scandinavian raceway</td><td>57.2653</td><td>13.6042</td><td>anderstorp</td><td>Sweden</td><td>2026-08-10T18:42:17.271649Z</td><td>dbfs:/Volumes/formula1/landing/files/circuits.csv</td></tr><tr><td>avus</td><td>https://en.wikipedia.org/wiki/AVUS</td><td>avus</td><td>52.4806</td><td>13.2514</td><td>berlin</td><td>Germany</td><td>2026-08-10T18:42:17.271649Z</td><td>dbfs:/Volumes/formula1/landing/files/circuits.csv</td></tr><tr><td>bahrain</td><td>https://en.wikipedia.org/wiki/Bahrain_International_Circuit</td><td>bahrain international circuit</td><td>26.0325</td><td>50.5106</td><td>sakhir</td><td>Bahrain</td><td>2026-08-10T18:42:17.271649Z</td><td>dbfs:/Volumes/formula1/landing/files/circuits.csv</td></tr><tr><td>baku</td><td>https://en.wikipedia.org/wiki/Baku_City_Circuit</td><td>baku city circuit</td><td>40.3725</td><td>49.8533</td><td>baku</td><td>Azerbaijan</td><td>2026-08-10T18:42:17.271649Z</td><td>dbfs:/Volumes/formula1/landing/files/circuits.csv</td></tr><tr><td>boavista</td><td>https://en.wikipedia.org/wiki/Circuito_da_Boavista</td><td>circuito da boavista</td><td>41.1705</td><td>-8.67325</td><td>oporto</td><td>Portugal</td><td>2026-08-10T18:42:17.271649Z</td><td>dbfs:/Volumes/formula1/landing/files/circuits.csv</td></tr><tr><td>brands_hatch</td><td>https://en.wikipedia.org/wiki/Brands_Hatch</td><td>brands hatch</td><td>51.3569</td><td>0.263056</td><td>kent</td><td>UK</td><td>2026-08-10T18:42:17.271649Z</td><td>dbfs:/Volumes/formula1/landing/files/circuits.csv</td></tr><tr><td>bremgarten</td><td>https://en.wikipedia.org/wiki/Circuit_Bremgarten</td><td>circuit bremgarten</td><td>46.9589</td><td>7.40194</td><td>bern</td><td>Switzerland</td><td>2026-08-10T18:42:17.27164 ...

# %% [markdown]
# #### Step 3 - Write to bronze delta table

# %%
(
    circuits_final_df
        .write
        .format('delta') # Recommended format
        .mode('overwrite') # Could be append or overwrite
        .saveAsTable(table_name)
)

# %%
# %sql
SELECT * FROM formula1.bronze.circuits
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>circuitId</th><th>url</th><th>circuitName</th><th>lat</th><th>long</th><th>locality</th><th>country</th><th>ingestion_timestamp</th><th>source_file</th></tr></thead><tbody><tr><td>null</td><td>https://en.wikipedia.org/wiki/Circuit_Gilles_Villeneuve</td><td>circuit gilles villeneuve</td><td>45.5</td><td>-73.5228</td><td>montreal</td><td>Canada</td><td>2026-08-10T18:42:17.721479Z</td><td>dbfs:/Volumes/formula1/landing/files/circuits.csv</td></tr><tr><td>null</td><td>https://en.wikipedia.org/wiki/Lusail_International_Circuit</td><td>losail international circuit</td><td>25.49</td><td>51.4542</td><td>lusail</td><td>Qatar</td><td>2026-08-10T18:42:17.721479Z</td><td>dbfs:/Volumes/formula1/landing/files/circuits.csv</td></tr><tr><td